# %%
import pandas as pd

# %%
elc_2014 =pd.read_csv("D:/Power_BI/RPC11_Input_For_Participants/datasets/constituency_wise_results_2014.csv")

# %%
elc_2014
# Out:
#                state     pc_name             candidate  sex   age category  \
# 0     Andhra Pradesh   Adilabad           GODAM NAGESH    M  49.0       ST
# 1     Andhra Pradesh   Adilabad                 NARESH    M  37.0       ST
# 2     Andhra Pradesh   Adilabad          RAMESH RATHOD    M  48.0       ST
# 3     Andhra Pradesh   Adilabad        RATHOD SADASHIV    M  55.0       ST
# 4     Andhra Pradesh   Adilabad       NETHAWATH RAMDAS    M  44.0       ST
# ...              ...         ...                   ...  ...   ...      ...
# 8350      Puducherry  Puducherry  PUVALA NAGESWARA RAO    M  60.0      GEN
# 8351      Puducherry  Puducherry            K. MANJINI    M  41.0      GEN
# 8352      Puducherry  Puducherry            R. VALAVAN    M  40.0      GEN
# 8353      Puducherry  Puducherry             V. VIJAYA    F  29.0      GEN
# 8354      Puducherry  Puducherry     None of the Above  NaN   NaN      NaN
#
# ...

# %%
elc_2019 =pd.read_csv("D:/Power_BI/RPC11_Input_For_Participants/datasets/constituency_wise_results_2019.csv")
elc_2019.head()
# Out:
#             state pc_name                                          candidate  \
# 0  Andhra Pradesh  Aruku                                 KISHORE CHANDRA DEO
# 1  Andhra Pradesh  Aruku   Dr. KOSURI KASI VISWANADHA VEERA VENKATA SATYA...
# 2  Andhra Pradesh  Aruku                                    GODDETI. MADHAVI
# 3  Andhra Pradesh  Aruku                              SHRUTI DEVI VYRICHERLA
# 4  Andhra Pradesh  Aruku                                 GANGULAIAH VAMPURU.
#
#       sex   age category  party   party_symbol  general_votes  postal_votes  \
# 0    MALE  72.0       ST    TDP        Bicycle         336163          1938
# 1    MALE  54.0       ST    BJP          Lotus          17578           289
# 2  FEMALE  26.0       ST  YSRCP    Ceiling Fan         557561          4629
# 3  FEMALE  46.0       ST    INC           Hand          17656            74
# 4    MALE  49.0       ST    JnP  Glass Tumbler          42245           549
#
#    total_votes  total_electors
# ...

# %%
print((elc_2014['pc_name'].unique()))
# Out:
# ['Adilabad ' 'Peddapalle ' 'Karimnagar ' 'Nizamabad' 'Zahirabad' 'Medak'
#  'Malkajgiri' 'Secundrabad' 'Hyderabad' 'CHELVELLA' 'Mahbubnagar'
#  'Nagarkurnool' 'Nalgonda' 'Bhongir ' 'Warangal' 'Mahabubabad  '
#  'Khammam ' 'Aruku ' 'Srikakulam' 'Vizianagaram' 'Visakhapatnam'
#  'Anakapalli' 'Kakinada' 'Amalapuram ' 'Rajahmundry' 'Narsapuram' 'Eluru '
#  'Machilipatnam ' 'Vijayawada' 'Guntur' 'Narasaraopet' 'Bapatla '
#  'Ongole ' 'Nandyal' 'Kurnool' 'Anantapur' 'Hindupur' 'Kadapa' 'Nellore'
#  'Tirupati ' 'Rajampet' 'Chittoor ' 'ARUNACHAL WEST' 'ARUNACHAL EAST'
#  'Karimganj ' 'Silchar' 'Autonomous District' 'Dhubri' 'Kokrajhar'
#  'Barpeta' 'Gauhati' 'Mangaldoi' 'Tezpur' 'Nowgong' 'Kaliabor' 'Jorhat'
#  'Dibrugarh' 'Lakhimpur' 'Valmiki Nagar' 'Paschim Champaran'
#  'Purvi Champaran' 'Sheohar' 'Sitamarhi' 'Madhubani' 'Jhanjharpur'
#  'Supaul' 'Araria' 'Kishanganj' 'Katihar' 'Purnia' 'Madhepura' 'Darbhanga'
#  'Muzaffarpur' 'Vaishali' 'Gopalganj (SC)' 'Siwan' 'Maharajganj' 'Saran'
# ...

# %%
print((elc_2019['pc_name'].unique()))
# Out:
# ['Aruku ' 'Srikakulam' 'Vizianagaram' 'Visakhapatnam' 'Anakapalli'
#  'Kakinada' 'Amalapuram ' 'Rajahmundry' 'Narsapuram' 'Eluru '
#  'Machilipatnam ' 'Vijayawada' 'Guntur' 'Narasaraopet' 'Bapatla '
#  'Ongole ' 'Nandyal' 'Kurnool' 'Anantapur' 'Hindupur' 'Kadapa' 'Nellore'
#  'Tirupati ' 'Rajampet' 'Chittoor ' 'ARUNACHAL WEST' 'ARUNACHAL EAST'
#  'Karimganj ' 'Silchar' 'Autonomous District' 'Dhubri' 'Kokrajhar'
#  'Barpeta' 'Gauhati' 'Mangaldoi' 'Tezpur' 'Nowgong' 'Kaliabor' 'Jorhat'
#  'Dibrugarh' 'Lakhimpur' 'Valmiki Nagar' 'Paschim Champaran'
#  'Purvi Champaran' 'Sheohar' 'Sitamarhi' 'Madhubani' 'Jhanjharpur'
#  'Supaul' 'Araria' 'Kishanganj' 'Katihar' 'Purnia' 'Madhepura' 'Darbhanga'
#  'Muzaffarpur' 'Vaishali' 'Gopalganj (SC)' 'Siwan' 'Maharajganj' 'Saran'
#  'Hajipur (SC)' 'Ujiarpur' 'Samastipur (SC)' 'Begusarai' 'Khagaria'
#  'Bhagalpur' 'Banka' 'Munger' 'Nalanda' 'Patna Sahib' 'Pataliputra'
#  'Arrah' 'Buxar' 'Sasaram (SC)' 'Karakat' 'Jahanabad' 'Aurangabad'
# ...

# %%
elc_2014[elc_2014['state']=='Andhra Pradesh']['pc_name'].unique()
# Out:
# array(['Adilabad ', 'Peddapalle ', 'Karimnagar ', 'Nizamabad',
#        'Zahirabad', 'Medak', 'Malkajgiri', 'Secundrabad', 'Hyderabad',
#        'CHELVELLA', 'Mahbubnagar', 'Nagarkurnool', 'Nalgonda', 'Bhongir ',
#        'Warangal', 'Mahabubabad  ', 'Khammam ', 'Aruku ', 'Srikakulam',
#        'Vizianagaram', 'Visakhapatnam', 'Anakapalli', 'Kakinada',
#        'Amalapuram ', 'Rajahmundry', 'Narsapuram', 'Eluru ',
#        'Machilipatnam ', 'Vijayawada', 'Guntur', 'Narasaraopet',
#        'Bapatla ', 'Ongole ', 'Nandyal', 'Kurnool', 'Anantapur',
#        'Hindupur', 'Kadapa', 'Nellore', 'Tirupati ', 'Rajampet',
#        'Chittoor '], dtype=object)

# %%
len(elc_2014[elc_2014['state']=='Andhra Pradesh']['pc_name'].unique())
# Out:
# 42

# %%
elc_2019[elc_2019['state']=='Telangana']['pc_name'].unique()
# Out:
# array(['Adilabad ', 'Peddapalle ', 'Karimnagar ', 'Nizamabad',
#        'Zahirabad', 'Medak', 'Malkajgiri', 'Secundrabad', 'Hyderabad',
#        'CHEVELLA', 'Mahbubnagar', 'Nagarkurnool', 'Nalgonda', 'Bhongir ',
#        'Warangal', 'Mahabubabad  ', 'Khammam '], dtype=object)

# %%
len(elc_2019[elc_2019['state']=='Telangana']['pc_name'].unique())
# Out:
# 17

# %%
pc_names_list=['Adilabad ', 'Peddapalle ', 'Karimnagar ', 'Nizamabad',
       'Zahirabad', 'Medak', 'Malkajgiri', 'Secundrabad', 'Hyderabad',
       'CHEVELLA', 'Mahbubnagar', 'Nagarkurnool', 'Nalgonda', 'Bhongir ',
       'Warangal', 'Mahabubabad  ', 'Khammam ']

# %%
pc_names_list=['Adilabad ', 'Peddapalle ', 'Karimnagar ', 'Nizamabad',
       'Zahirabad', 'Medak', 'Malkajgiri', 'Secundrabad', 'Hyderabad',
       'CHEVELLA', 'Mahbubnagar', 'Nagarkurnool', 'Nalgonda', 'Bhongir ',
       'Warangal', 'Mahabubabad  ', 'Khammam ']

elc_2014.loc[elc_2014['pc_name'].isin(pc_names_list), 'state'] = 'Telangana'

# %%
elc_2014.to_csv('constituency_wise_results_2014_cleaned.csv')

# %%
len(elc_2014[elc_2014['state']=='Andhra Pradesh']['pc_name'].unique())
# Out:
# 26

# %%
pd.read_csv("D:/Power_BI/RPC11_Input_For_Participants/constituency_wise_results_2014_cleaned")
# Out:
#       Unnamed: 0       state     pc_name             candidate  sex   age  \
# 0              0   Telangana   Adilabad           GODAM NAGESH    M  49.0
# 1              1   Telangana   Adilabad                 NARESH    M  37.0
# 2              2   Telangana   Adilabad          RAMESH RATHOD    M  48.0
# 3              3   Telangana   Adilabad        RATHOD SADASHIV    M  55.0
# 4              4   Telangana   Adilabad       NETHAWATH RAMDAS    M  44.0
# ...          ...         ...         ...                   ...  ...   ...
# 8350        8350  Puducherry  Puducherry  PUVALA NAGESWARA RAO    M  60.0
# 8351        8351  Puducherry  Puducherry            K. MANJINI    M  41.0
# 8352        8352  Puducherry  Puducherry            R. VALAVAN    M  40.0
# 8353        8353  Puducherry  Puducherry             V. VIJAYA    F  29.0
# 8354        8354  Puducherry  Puducherry     None of the Above  NaN   NaN
#
#      category party    party_symbol  general_votes  postal_votes  total_votes  \
# ...

# %%
print(elc_2014['pc_name'].unique())
# Out:
# ['Adilabad ' 'Peddapalle ' 'Karimnagar ' 'Nizamabad' 'Zahirabad' 'Medak'
#  'Malkajgiri' 'Secundrabad' 'Hyderabad' 'CHELVELLA' 'Mahbubnagar'
#  'Nagarkurnool' 'Nalgonda' 'Bhongir ' 'Warangal' 'Mahabubabad  '
#  'Khammam ' 'Aruku ' 'Srikakulam' 'Vizianagaram' 'Visakhapatnam'
#  'Anakapalli' 'Kakinada' 'Amalapuram ' 'Rajahmundry' 'Narsapuram' 'Eluru '
#  'Machilipatnam ' 'Vijayawada' 'Guntur' 'Narasaraopet' 'Bapatla '
#  'Ongole ' 'Nandyal' 'Kurnool' 'Anantapur' 'Hindupur' 'Kadapa' 'Nellore'
#  'Tirupati ' 'Rajampet' 'Chittoor ' 'ARUNACHAL WEST' 'ARUNACHAL EAST'
#  'Karimganj ' 'Silchar' 'Autonomous District' 'Dhubri' 'Kokrajhar'
#  'Barpeta' 'Gauhati' 'Mangaldoi' 'Tezpur' 'Nowgong' 'Kaliabor' 'Jorhat'
#  'Dibrugarh' 'Lakhimpur' 'Valmiki Nagar' 'Paschim Champaran'
#  'Purvi Champaran' 'Sheohar' 'Sitamarhi' 'Madhubani' 'Jhanjharpur'
#  'Supaul' 'Araria' 'Kishanganj' 'Katihar' 'Purnia' 'Madhepura' 'Darbhanga'
#  'Muzaffarpur' 'Vaishali' 'Gopalganj (SC)' 'Siwan' 'Maharajganj' 'Saran'
# ...

# %%
len(elc_2014['pc_name'].unique())
# Out:
# 508

# %%
len(elc_2019['pc_name'].unique())
# Out:
# 540
